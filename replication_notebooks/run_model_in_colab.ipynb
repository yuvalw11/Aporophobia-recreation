# %%
import multiprocessing as mp
mp.cpu_count()
# Out:
# 2

# %% [markdown]
# Here we mount the google drive with our recreation repository

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Aporophobia-recreation"
# !mkdir ./my_results
# Out:
# Mounted at /content/drive

# %% [markdown]
# Installing requirements

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 58.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 60.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Run the model with parameters from the paper

# %%
# !python3 run_model.py -P ./my_results -M 10 -T 2880 -N 100
# Out:
# Streaming output truncated to the last 5000 lines.
# step 2552/2880 simulation id: 5050:0, norms config: 63:0-1-2-3-4-5
# step 2195/2880 simulation id: 5057:0, norms config: 63:0-1-2-3-4-5
# step 1697/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 1698/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 1699/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 1700/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 1701/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 2801/2880 simulation id: 5054:0, norms config: 63:0-1-2-3-4-5
# step 1702/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 2802/2880 simulation id: 5054:0, norms config: 63:0-1-2-3-4-5
# step 1703/2880 simulation id: 5059:0, norms config: 63:0-1-2-3-4-5
# step 155/2880 simulation id: 5055:0, norms config: 63:0-1-2-3-4-5
# step 2803/2880 simulation id: 5054:0, norms config: 63:0-1-2-3-4-5
# ...
